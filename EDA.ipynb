# %% [markdown]
# # AI Mathematical Olympiad - Progress Prize 3
# # (AI数学オリンピック - Progress Prize 3)
#
# ## 1. Introduction / はじめに
# This notebook covers the initial setup, data loading, and basic exploration for the competition.
#
# (このNotebookでは、コンペティションの初期セットアップ、データの読み込み、および基本的なデータ確認を行います。)
#
# **Objective:** Solve mathematical problems using AI.
#
# (**目的:** AIを用いて数学の問題を解くことです。)

# %%
import pandas as pd
import numpy as np
import os

# Check available files / フォルダ内のファイルを確認
data_dir = '.'
print("Files in directory (現在のディレクトリ内のファイル):")
print(os.listdir(data_dir))

# %% [markdown]
# ## 2. Load Data / データの読み込み
# Attempting to load standard competition files. Please ensure you have downloaded and unzipped the data into this directory.
#
# (コンペティションのデータを読み込みます。データをダウンロードし、このフォルダに解凍していることを確認してください。)

# %%
try:
    if os.path.exists('train.csv'):
        train_df = pd.read_csv('train.csv')
        print("Train data loaded properly (学習データの読み込み完了):")
        display(train_df.head())
    else:
        print("train.csv not found. Please download data from Kaggle.")
        print("(train.csv が見つかりません。Kaggleからデータをダウンロードして配置してください。)")
        
    if os.path.exists('test.csv'):
        test_df = pd.read_csv('test.csv')
        print("\nTest data loaded properly (テストデータの読み込み完了):")
        display(test_df.head())
except Exception as e:
    print(f"Error loading data (データの読み込みエラー): {e}")
